# %%
import sys
# Add repo path
sys.path.append("/Workspace/Users/dhiraj.dhande.de@gmail.com/data_injestion_proj/adls-adls_injestion/")

source_file_path = 'abfss://inbound@storageaccdb.dfs.core.windows.net/employees/emp.txt'
target_file_path = 'abfss://outbound@storageaccdb.dfs.core.windows.net/employees/'

# %%
from src.reader import read_csv_from_adls
from src.transformer import transform_employee_data
from src.writer import write_csv_to_adls

# %%
df= read_csv_from_adls(spark, source_file_path)
df.show()

# %%
df_transformed = transform_employee_data(df)
display(df_transformed)

# %%
write_csv_to_adls(df_transformed, target_file_path)
