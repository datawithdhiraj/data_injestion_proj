# %%
import sys
import os
repo_path = "/Workspace/Users/dhiraj.dhande.de@gmail.com/data_injestion_proj/adls-adls_injestion"
sys.path.append(repo_path)

from src.transformer import transform_employee_data

# %%
data = [(1,"Amit",40000),(2,"Rahul",20000)]
df = spark.createDataFrame(data, ["id","name","salary"])
result = transform_employee_data(df)
count = result.count()

print(f"Result count: {count}")

assert count == 1, f"Test failed: Expected 1 but got {count}"

print("Test passed successfully")
